# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df =pd.read_csv(r"C:\Users\RaviKiran\OneDrive\Desktop\Data Science\Bootcamp practise files\examdata.txt.csv")

# %%
df.head()

# %%
df['math score'].sort_values(ascending =False)[:5]
# Out:
# 495    100
# 91     100
# 128    100
# 911    100
# 565    100
# Name: math score, dtype: int64

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2    male        group C                some college  free/reduced
# 3  female        group D           bachelor's degree  free/reduced
# 4    male        group D                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          74             68             67
# 1               completed          58             68             66
# 2                    none          66             65             65
# 3                    none          74             75             73
# 4                    none          78             77             71

# %% [markdown]
# # Renaming

# %%
df=df.rename(columns ={'parental level of education' :'parental_level_of_education','test preparation course':'test_preparation_course','math score':'math_score','reading score':'reading_score','writing score':'writing_score'})

# %%
df
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0      male        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2      male        group C                some college  free/reduced
# 3    female        group D           bachelor's degree  free/reduced
# 4      male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group C            some high school      standard
# 996  female        group E                some college      standard
# 997  female        group E          associate's degree  free/reduced
# 998  female        group C                 high school      standard
# 999    male        group C                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
sma_data =pd.read_csv(r"C:\Users\RaviKiran\OneDrive\Desktop\Data Science\Bootcamp practise files\smad.csv")

# %%
sma_data
# Out:
#     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 0        1384          78.1            12.3       25627          69678
# 1        3719          43.9             9.4       13326          43292
# 2        3553          37.4            10.7        9724          33731
# 3        3916          29.9             8.8        6402          24167
# 4        2480          31.5            10.5        8502          16751
# ..        ...           ...             ...         ...            ...
# 94       1511          38.7            10.7         348           1093
# 95       1543          39.6             8.1         159            481
# 96       1011          37.8            10.5         264            964
# 97        813          13.4            10.9         371           4355
# 98        654          28.8             3.9         140           1296
#
#     graduates  work_force  income  region  crime_rate
# 0        50.1      4083.9   72100       1       75.55
# ...

# %%
sorted_data1 =sma_data['crime_rate'].sort_values (ascending = False)

# %%
sorted_data1.head()
# Out:
# 20    85.62
# 74    82.68
# 53    80.94
# 4     80.19
# 67    78.10
# Name: crime_rate, dtype: float64

# %%
sma_data['region'][20:76],sorted_data1[20:76]
# Out:
# (20    4
#  21    2
#  22    3
#  23    2
#  24    1
#  25    4
#  26    3
#  27    3
#  28    1
#  29    2
#  30    3
#  31    3
#  32    3
#  33    4
#  34    3
#  35    2
#  36    1
#  37    2
#  38    1
#  39    1
#  40    3
#  41    3
#  42    3
#  43    1
#  44    2
#  45    2
#  46    1
#  47    3
#  48    2
#  49    3
#  50    3
#  51    3
#  52    3
#  53    4
#  54    4
#  55    1
#  56    2
#  57    3
#  58    1
#  59    4
#  60    3
#  61    2
#  62    3
#  63    3
#  64    2
#  65    2
#  66    3
#  67    4
#  68    3
#  69    3
#  70    1
#  71    2
#  72    1
#  73    4
#  74    4
#  75    1
#  Name: region, dtype: int64,
#  33    64.98
#  91    64.91
#  7     64.88
#  16    64.68
#  14    64.05
#  61    63.67
#  84    63.44
#  52    63.22
#  13    63.20
#  81    63.10
#  19    63.04
#  93    62.63
#  41    62.09
#  34    61.97
#  71    61.46
#  22    61.15
#  49    60.77
#  96    60.16
#  29    59.48
#  57    58.97
#  55    58.79
#  5     58.48
#  47    58.33
# ...

# %%
sma_data.isna()

# %%
sma_data.isnull()
